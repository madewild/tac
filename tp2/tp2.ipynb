# %% [markdown]
# # TP2 : Exploration de l'annnée XXX

# %% [markdown]
# ## 1. Récupération du contenu du texte

# %% [markdown]
# ## 1. Keywords

# %%
import os
import yake

# %%
# Instantier l'extracteur de mots clés
kw_extractor = yake.KeywordExtractor(lan="fr", top=50)
kw_extractor

# %%
print(keywords)

# %% [markdown]
# ## 2. Named Entity Recognition
